# %% [markdown]
# **Practical No.1 :-**

# %% [markdown]
# **Aim :-** Introduction to OpenCV.

# %%
# Uploading the file 
from google.colab import files
up = files.upload()
# Out:
#      <input type="file" id="files-7b60dd5c-ba60-47e6-b382-b1e54981f792" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b60dd5c-ba60-47e6-b382-b1e54981f792">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Image.png to Image (1).png

# %%
#Importing the open cv
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#To read image cv2.imread function
image = cv2.imread("Image.png", cv2.IMREAD_COLOR)
#Creating GUI window to display an image on screen
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=328x355 at 0x7FC701AB4D10>

# %%
#Finding the Data type of the Image
print("The Data type of the image is :-", image.dtype)
# Out:
# The Data type of the image is :- uint8

# %%
#creating GUI window to display the image
cv2_imshow(image)
#for removing/deleting created GUI window from screen and memory
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=328x355 at 0x7FC6F2C8CD10>

# %%
rows,cols = image.shape[:2]
#(col/2,rows/2) is the center of rotation for the image
# M is the cordinates of the center
M = cv2.getRotationMatrix2D((cols/2,rows/2),90,1)
dst = cv2.warpAffine(image,M,(cols,rows))
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=328x355 at 0x7F3CA1FE6B10>

# %%
#converting image to Gray scale
gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
print(gray_image)
#plotting the grayscale image
cv2_imshow(gray_image)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# <PIL.Image.Image image mode=L size=328x355 at 0x7F3CA203FC50>

# %%
#converting image to HSV format
hsv_image = cv2.cvtColor(image,cv2.COLOR_BGR2HSV)
#print(hsv_image)
#plotting the HSV image
cv2_imshow(hsv_image)
# Out:
# <PIL.Image.Image image mode=RGB size=328x355 at 0x7F3CA20A6BD0>

# %%
# Canny Edge Detection
edges = cv2.Canny(image=image, threshold1=100, threshold2=200) # Canny Edge Detection
# Display Canny Edge Detection Image
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=328x355 at 0x7FC6F0E7E890>
